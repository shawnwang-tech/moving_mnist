# %%
from fastai.vision.all import *
from moving_mnist.models.conv_rnn import *
from moving_mnist.data import *
from heat.data import *

# %%
if torch.cuda.is_available():
    torch.cuda.set_device(2)
    print(torch.cuda.get_device_name())
# Out:
# GeForce RTX 2080 Ti

# %% [markdown]
# # Train Example:

# %% [markdown]
# We wil predict:
# - `n_in`: 5 images
# - `n_out`: 5 images
# - `n_obj`: up to 3 objects

# %%
DATA_PATH = "/data/wangshuo/data/heat_diffusion/heat_diffusion_batch_128_size_64x64_objs_1.npy"

# %%
ds = Heat(DATA_PATH)

# %%
train_tl = TfmdLists(range(120), ImageTupleTransform(ds))
valid_tl = TfmdLists(range(120), ImageTupleTransform(ds))

# %%
dls = DataLoaders.from_dsets(train_tl, valid_tl, bs=32,
                             after_batch=[Normalize.from_stats(imagenet_stats[0][0], 
                                                               imagenet_stats[1][0])]).cuda()

# %%
loss_func = StackLoss(MSELossFlat())

# %% [markdown]
# Left: Input, Right: Target

# %%
dls.show_batch()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-90634fcc3c9e> in <module>
# ----> 1 dls.show_batch()
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/data/core.py in show_batch(self, b, max_n, ctxs, show, unique, **kwargs)
#     100         if b is None: b = self.one_batch()
#     101         if not show: return self._pre_show_batch(b, max_n=max_n)
# --> 102         show_batch(*self._pre_show_batch(b, max_n=max_n), ctxs=ctxs, max_n=max_n, **kwargs)
#     103         if unique: self.get_idxs = old_get_idxs
#     104
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastcore/dispatch.py in __call__(self, *args, **kwargs)
#     127         elif self.inst is not None: f = MethodType(f, self.inst)
#     128         elif self.owner is not None: f = MethodType(f, self.owner)
# --> 129         return f(*args, **kwargs)
#     130
#     131     def __get__(self, inst, owner):
#
# ~/workspace/moving_mnist/heat/data.py in show_batch(x, y, samples, ctxs, max_n, nrows, ncols, figsize, **kwargs)
#      47
#      48 # Cell
# ---> 49 class ImageTupleTransform(Transform):
#      50     def __init__(self, ds, cl_type=TensorImageBW):
#      51         self.ds = ds
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
b = dls.one_batch()
explode_types(b)
# Out:
# {tuple: [{heat.data.ImageSeq: [fastai.torch_core.TensorImageBW,
#     fastai.torch_core.TensorImageBW,
#     fastai.torch_core.TensorImageBW,
#     fastai.torch_core.TensorImageBW,
#     fastai.torch_core.TensorImageBW]},
#   {heat.data.ImageSeq: [fastai.torch_core.TensorImageBW,
#     fastai.torch_core.TensorImageBW,
#     fastai.torch_core.TensorImageBW,
#     fastai.torch_core.TensorImageBW,
#     fastai.torch_core.TensorImageBW]}]}

# %% [markdown]
# `StackUnstack` takes cares of stacking the list of images into a fat tensor, and unstacking them at the end, we will need to modify our loss function to take a list of tensors as input and target.

# %% [markdown]
# ## Simple model

# %%
model = StackUnstack(SimpleModel())

# %% [markdown]
# As the `ImageSeq` is a `tuple` of images, we will need to stack them to compute loss.

# %%
learn = Learner(dls, model, loss_func=loss_func, cbs=[]).to_fp16()

# %% [markdown]
# I have a weird bug that if I use `nn.LeakyReLU` after doing `learn.lr_find()` the model does not train (the loss get stucked).

# %%
x,y = dls.one_batch()

# %%
learn.lr_find()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-143-d81c6bd29d71> in <module>
# ----> 1 learn.lr_find()
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/callback/schedule.py in lr_find(self, start_lr, end_lr, num_it, stop_div, show_plot, suggestions)
#     226     n_epoch = num_it//len(self.dls.train) + 1
#     227     cb=LRFinder(start_lr=start_lr, end_lr=end_lr, num_it=num_it, stop_div=stop_div)
# --> 228     with self.no_logging(): self.fit(n_epoch, cbs=cb)
#     229     if show_plot: self.recorder.plot_lr_find()
#     230     if suggestions:
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastcore/logargs.py in _f(*args, **kwargs)
#      54         init_args.update(log)
#      55         setattr(inst, 'init_args', init_args)
# ---> 56         return inst if to_return else f(*args, **kwargs)
#      57     return _f
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt)
#     205             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     206             self.n_epoch = n_epoch
# --> 207             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     208
#     209     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     153
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#     157         finally:   self(f'after_{event_type}')        ;final()
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/learner.py in _do_fit(self)
#     195         for epoch in range(self.n_epoch):
#     196             self.epoch=epoch
# --> 197             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     198
#     199     @log_args(but='cbs')
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     153
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#     157         finally:   self(f'after_{event_type}')        ;final()
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/learner.py in _do_epoch(self)
#     189
#     190     def _do_epoch(self):
# --> 191         self._do_epoch_train()
#     192         self._do_epoch_validate()
#     193
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/learner.py in _do_epoch_train(self)
#     181     def _do_epoch_train(self):
#     182         self.dl = self.dls.train
# --> 183         self._with_events(self.all_batches, 'train', CancelTrainException)
#     184
#     185     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     153
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#     157         finally:   self(f'after_{event_type}')        ;final()
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/learner.py in all_batches(self)
#     159     def all_batches(self):
#     160         self.n_iter = len(self.dl)
# --> 161         for o in enumerate(self.dl): self.one_batch(*o)
#     162
#     163     def _do_one_batch(self):
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/learner.py in one_batch(self, i, b)
#     177         self.iter = i
#     178         self._split(b)
# --> 179         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     180
#     181     def _do_epoch_train(self):
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     153
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#     157         finally:   self(f'after_{event_type}')        ;final()
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/learner.py in _do_one_batch(self)
#     162
#     163     def _do_one_batch(self):
# --> 164         self.pred = self.model(*self.xb)
#     165         self('after_pred')
#     166         if len(self.yb): self.loss = self.loss_func(self.pred, *self.yb)
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/workspace/moving_mnist/moving_mnist/models/conv_rnn.py in forward(self, *args)
#     252     def forward(self, *args):
#     253         inputs = [torch.stack(x, dim=self.dim) for x in args]
# --> 254         outputs = self.module(*inputs)
#     255         if isinstance(outputs, (tuple, list)):
#     256             return [self.unbind_images(output, dim=self.dim) for output in outputs]
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/workspace/moving_mnist/moving_mnist/models/conv_rnn.py in forward(self, x)
#     266         self.decoder = Decoder(n_out, szs[::-1], ks, rnn_ks, act, blur, attn, norm, debug)
#     267     def forward(self, x):
# --> 268         enc_outs, h = self.encoder(x)
#     269         if self.strategy is 'zero':
#     270             dec_in = one_param(self).new_zeros(*enc_outs[-1].shape)
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/workspace/moving_mnist/moving_mnist/models/conv_rnn.py in forward(self, inputs)
#     163         for i, (conv, rnn) in enumerate(zip(self.convs, self.rnns)):
#     164             if self.debug: print('stage: ',i)
# --> 165             inputs, state_stage = self.forward_by_stage(inputs, conv, rnn)
#     166             outputs.append(inputs)
#     167             hidden_states.append(state_stage)
#
# ~/workspace/moving_mnist/moving_mnist/models/conv_rnn.py in forward_by_stage(self, inputs, conv, rnn)
#     150             print(f' Layer: {rnn}')
#     151             print(' inputs: ', inputs.shape)
# --> 152         inputs = conv(inputs)
#     153         if self.debug: print(' after_convs: ', inputs.shape)
#     154         outputs_stage, state_stage = rnn(inputs, None)
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/workspace/moving_mnist/moving_mnist/models/conv_rnn.py in forward(self, *args, **kwargs)
#     113             inp_shape = args[0].shape
#     114             bs, seq_len = inp_shape[0], inp_shape[1]
# --> 115             out = self.module(*[x.view(bs*seq_len, *x.shape[2:]) for x in args], **kwargs)
#     116             out_shape = out.shape
#     117             return out.view(bs, seq_len,*out_shape[1:])
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     421
#     422     def forward(self, input: Tensor) -> Tensor:
# --> 423         return self._conv_forward(input, self.weight)
#     424
#     425 class Conv3d(_ConvNd):
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight)
#     418                             _pair(0), self.dilation, self.groups)
#     419         return F.conv2d(input, weight, self.bias, self.stride,
# --> 420                         self.padding, self.dilation, self.groups)
#     421
#     422     def forward(self, input: Tensor) -> Tensor:
#
# ~/.pyenv/versions/3.7.3/envs/py373torch17/lib/python3.7/site-packages/fastai/torch_core.py in __torch_function__(self, func, types, args, kwargs)
#     314
#     315     def __torch_function__(self, func, types, args=(), kwargs=None):
# --> 316         with torch._C.DisableTorchFunction(): ret = _convert(func(*args, **(kwargs or {})), self.__class__)
#     317         if isinstance(ret, TensorBase): ret.set_meta(self, as_copy=True)
#     318         return ret
#
# RuntimeError: Given groups=1, weight of size [16, 1, 3, 3], expected input[5, 32, 64, 64] to have 1 channels, but got 32 channels instead

# %%
learn.fit_one_cycle(10, 1e-4)

# %%
p,t = learn.get_preds()

# %% [markdown]
# As you can see, the results is a list of 5 tensors with 100 samples each.

# %%
len(p), p[0].shape
# Out:
# (5, torch.Size([100, 1, 64, 64]))

# %%
def show_res(t, idx):
    im_seq = ImageSeq.create([t[i][idx] for i in range(5)])
    im_seq.show(figsize=(8,4));

# %%
k = random.randint(0,100)
show_res(t,k)
show_res(p,k)

# %% [markdown]
# ## A bigger Decoder

# %% [markdown]
# We will pass:
# - `blur`: to use blur on the upsampling path (this is done by using and a poolling layer and a replication)
# - `attn`: to include a self attention layer on the decoder

# %%
model2 = StackUnstack(SimpleModel(szs=[16,64,96], act=partial(nn.LeakyReLU, 0.2, inplace=True),blur=True, attn=True))

# %% [markdown]
# We have to reduce batch size as the self attention layer is heavy.

# %%
dls = DataLoaders.from_dsets(train_tl, valid_tl, bs=8,
                             after_batch=[Normalize.from_stats(imagenet_stats[0][0], 
                                                               imagenet_stats[1][0])]).cuda()

# %%
learn2 = Learner(dls, model2, loss_func=loss_func, cbs=[]).to_fp16()

# %%
learn2.lr_find()
# Out:
# SuggestedLRs(lr_min=0.0033113110810518267, lr_steep=0.0002290867705596611)

# %%
learn2.fit_one_cycle(10, 1e-4)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='676' class='' max='937' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       72.15% [676/937 02:59<01:09 0.5494]
#     </div>

# %%
p,t = learn2.get_preds()

# %% [markdown]
# As you can see, the results is a list of 5 tensors with 100 samples each.

# %%
len(p), p[0].shape

# %%
def show_res(t, idx):
    im_seq = ImageSeq.create([t[i][idx] for i in range(5)])
    im_seq.show(figsize=(8,4));

# %%
k = random.randint(0,100)
show_res(t,k)
show_res(p,k)
